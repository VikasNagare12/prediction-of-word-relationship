# %%
from nltk.corpus import stopwords
from time import time
import os
import numpy as np
from collections import OrderedDict
import math

# %%
def timeit(method):
    def timed(*args, **kw):
        ts = time()
        result = method(*args, **kw)
        te = time()

        print( '%r (%r, %r) %2.2f sec' % (method.__name__, args, kw, te-ts) )
        return result
    return timed

# %%
from gensim.models import KeyedVectors
if not os.path.exists('GoogleNews-vectors-negative300.bin.gz'):
    raise ValueError("SKIP: You need to download the google news model")
start = time()
print("Loading Word Vectors...")
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True, limit=500000)
print('\nWord2vec model took %.2f seconds to load' % (time() - start))
stop_words = stopwords.words('english')
# Out:
# Loading Word Vectors...
#
# Word2vec model took 29.75 seconds to load
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
len(stop_words)
# Out:
# 179

# %%
with open('capitals_processed_final.csv') as input_file:
    capital_of = OrderedDict()
    for line in input_file:
        if line.strip():
            print(line)
            try:
                country, capital = line.split(",")
                country = country.strip()
                capital = capital.strip()
                if(country != capital):
                    print(country, capital, "added")
                    capital_of[country] = capital
                    # start = time()
                    # print('Query time %.2f' % (time() - start))
                else:
                    print("Country and capital do no have separate vector")
                
            except ValueError:
                print('Skipping {}'.format(line))
            # print("*" * 100)
    # vectors_tuple = tuple(vectors)
    # final_matrix = np.concatenate(vectors_tuple)
    # print(vectors[3].shape)
    # print(vectors[3])
    # print(type(final_matrix))
    # print(final_matrix.shape)
    # print(final_matrix)

# 300 * 300 plane of basis vectors
# Out:
# Afghanistan, Kabul
#
# Afghanistan Kabul added
# Albania,Tirana
#
# Albania Tirana added
# Algeria,Algiers
#
# Algeria Algiers added
# Andorra,Andorra la Vella
#
# Andorra Andorra la Vella added
# Angola, Luanda
#
# Angola Luanda added
# Antigua and Barbuda, Saint John's
#
# Antigua and Barbuda Saint John's added
# Argentina, Buenos Aires
#
# Argentina Buenos Aires added
# Armenia, Yerevan
#
# Armenia Yerevan added
# Australia, Canberra
#
# Australia Canberra added
# Austria, Vienna
#
# Austria Vienna added
# Azerbaijan, Baku
#
# Azerbaijan Baku added
# The Bahamas, Nassau
#
# The Bahamas Nassau added
# Bahrain, Manama
#
# Bahrain Manama added
# Bangladesh, Dhaka
#
# Bangladesh Dhaka added
# Barbados, Bridgetown
#
# Barbados Bridgetown added
# Belarus, Minsk
#
# Belarus Minsk added
# Belgium, Brussels
#
# Belgium Brussels added
# Belize, Belmopan
#
# Belize Belmopan added
# Benin, Porto,Novo
#
# Skipping Benin, Porto,Novo
#
# Bhutan, Thimphu
#
# Bhutan Thimphu added
# Bolivia, La Paz (administrative); Sucre (judicial)
#
# Bolivia La Paz (administrative); Sucre (judicial) added
# Bosnia and Herzegovina, Sarajevo
#
# Bosnia and Herzegovina Sarajevo added
# Botswana, Gaborone
#
# Botswana Gaborone added
# Brazil, Brasilia
#
# Brazil Brasilia added
# Brunei, Bandar Seri Begawan
#
# Brunei Bandar Seri Begawan added
# Bulgaria, Sofia
#
# Bulgaria Sofia added
# Burkina Faso, Ouagadougou
#
# Burkina Faso Ouagadougou added
# Burundi, Bujumbura
#
# Burundi Bujumbura added
# Cambodia, Phnom Penh
#
# Cambodia Phnom Penh added
# Cameroon, Yaounde
#
# Cameroon Yaounde added
# Canada, Ottawa
#
# Canada Ottawa added
# Cape Verde, Praia
#
# Cape Verde Praia added
# Central African Republic, Bangui
#
# Central African Republic Bangui added
# Chad, N'Djamena
#
# Chad N'Djamena added
# Chile, Santiago
#
# Chile Santiago added
# China, Beijing
#
# China Beijing added
# Colombia, Bogota
#
# Colombia Bogota added
# Comoros, Moroni
#
# Comoros Moroni added
# Congo, Republic of the, Brazzaville
#
# Skipping Congo, Republic of the, Brazzaville
#
# Congo, Democratic Republic of the, Kinshasa
#
# Skipping Congo, Democratic Republic of the, Kinshasa
#
# Costa Rica, San Jose
#
# Costa Rica San Jose added
# Cote d'Ivoire, Yamoussoukro (official); Abidjan (de facto)
#
# Cote d'Ivoire Yamoussoukro (official); Abidjan (de facto) added
# Croatia, Zagreb
#
# Croatia Zagreb added
# Cuba, Havana
#
# Cuba Havana added
# Cyprus, Nicosia
#
# Cyprus Nicosia added
# Czech Republic, Prague
#
# Czech Republic Prague added
# Denmark, Copenhagen
#
# Denmark Copenhagen added
# Djibouti, Djibouti
#
# Country and capital do no have separate vector
# Dominica, Roseau
#
# Dominica Roseau added
# Dominican Republic, Santo Domingo
#
# Dominican Republic Santo Domingo added
# East Timor (Timor,Leste), Dili
#
# Skipping East Timor (Timor,Leste), Dili
#
# Ecuador, Quito
#
# Ecuador Quito added
# Egypt, Cairo
#
# Egypt Cairo added
# El Salvador, San Salvador
#
# El Salvador San Salvador added
# Equatorial Guinea, Malabo
#
# Equatorial Guinea Malabo added
# Eritrea, Asmara
#
# Eritrea Asmara added
# Estonia, Tallinn
#
# Estonia Tallinn added
# Ethiopia, Addis Ababa
#
# Ethiopia Addis Ababa added
# Fiji, Suva
#
# Fiji Suva added
# Finland, Helsinki
#
# Finland Helsinki added
# France, Paris
#
# France Paris added
# Gabon, Libreville
#
# Gabon Libreville added
# The Gambia, Banjul
#
# The Gambia Banjul added
# Georgia, Tbilisi
#
# Georgia Tbilisi added
# Germany, Berlin
#
# Germany Berlin added
# Ghana, Accra
#
# Ghana Accra added
# Greece, Athens
#
# Greece Athens added
# Grenada, Saint George's
#
# Grenada Saint George's added
# Guatemala, Guatemala City
#
# Guatemala Guatemala City added
# Guinea, Conakry
#
# Guinea Conakry added
# Guinea,Bissau, Bissau
#
# Skipping Guinea,Bissau, Bissau
#
# Guyana, Georgetown
#
# Guyana Georgetown added
# Haiti, Port,au,Prince
#
# Skipping Haiti, Port,au,Prince
#
# Honduras, Tegucigalpa
#
# Honduras Tegucigalpa added
# Hungary, Budapest
#
# Hungary Budapest added
# Iceland, Reykjavik
#
# Iceland Reykjavik added
# India, New Delhi
#
# India New Delhi added
# Indonesia, Jakarta
#
# Indonesia Jakarta added
# Iran, Tehran
#
# Iran Tehran added
# Iraq, Baghdad
#
# Iraq Baghdad added
# Ireland, Dublin
#
# Ireland Dublin added
# Israel, Jerusalem*
#
# Israel Jerusalem* added
# Italy, Rome
#
# Italy Rome added
# Jamaica, Kingston
#
# Jamaica Kingston added
# Japan, Tokyo
#
# Japan Tokyo added
# Jordan, Amman
#
# Jordan Amman added
# Kazakhstan, Astana
#
# Kazakhstan Astana added
# Kenya, Nairobi
#
# Kenya Nairobi added
# Kiribati, Tarawa Atoll
#
# Kiribati Tarawa Atoll added
# Korea, North, Pyongyang
#
# Skipping Korea, North, Pyongyang
#
# Korea, South, Seoul
#
# Skipping Korea, South, Seoul
#
# Kosovo, Pristina
#
# Kosovo Pristina added
# Kuwait, Kuwait City
#
# Kuwait Kuwait City added
# Kyrgyzstan, Bishkek
#
# Kyrgyzstan Bishkek added
# Laos, Vientiane
#
# Laos Vientiane added
# Latvia, Riga
#
# Latvia Riga added
# Lebanon, Beirut
#
# Lebanon Beirut added
# Lesotho, Maseru
#
# Lesotho Maseru added
# Liberia, Monrovia
#
# Liberia Monrovia added
# Libya, Tripoli
#
# Libya Tripoli added
# Liechtenstein, Vaduz
#
# Liechtenstein Vaduz added
# Lithuania, Vilnius
#
# Lithuania Vilnius added
# Luxembourg, Luxembourg
#
# Country and capital do no have separate vector
# Macedonia, Skopje
#
# Macedonia Skopje added
# Madagascar, Antananarivo
#
# Madagascar Antananarivo added
# Malawi, Lilongwe
#
# Malawi Lilongwe added
# Malaysia, Kuala Lumpur
#
# Malaysia Kuala Lumpur added
# Maldives, Male
#
# Maldives Male added
# Mali, Bamako
#
# Mali Bamako added
# Malta, Valletta
#
# Malta Valletta added
# Marshall Islands, Majuro
#
# Marshall Islands Majuro added
# Mauritania, Nouakchott
#
# Mauritania Nouakchott added
# Mauritius, Port Louis
#
# Mauritius Port Louis added
# Mexico, Mexico City
#
# Mexico Mexico City added
# Micronesia, Federated States of, Palikir
#
# Skipping Micronesia, Federated States of, Palikir
#
# Moldova, Chisinau
#
# Moldova Chisinau added
# Monaco, Monaco
#
# Country and capital do no have separate vector
# Mongolia, Ulaanbaatar
#
# Mongolia Ulaanbaatar added
# Montenegro, Podgorica
#
# Montenegro Podgorica added
# Morocco, Rabat
#
# Morocco Rabat added
# Mozambique, Maputo
#
# Mozambique Maputo added
# Myanmar (Burma), Rangoon (Yangon); Naypyidaw or Nay Pyi Taw (administrative)
#
# Myanmar (Burma) Rangoon (Yangon); Naypyidaw or Nay Pyi Taw (administrative) added
# Namibia, Windhoek
#
# Namibia Windhoek added
# Nauru, no official capital; government offices in Yaren District
#
# Nauru no official capital; government offices in Yaren District added
# Nepal, Kathmandu
#
# Nepal Kathmandu added
# Netherlands, Amsterdam; The Hague (seat of government)
#
# Netherlands Amsterdam; The Hague (seat of government) added
# New Zealand, Wellington
#
# New Zealand Wellington added
# Nicaragua, Managua
#
# Nicaragua Managua added
# Niger, Niamey
#
# Niger Niamey added
# Nigeria, Abuja
#
# Nigeria Abuja added
# Norway, Oslo
#
# Norway Oslo added
# Oman, Muscat
#
# Oman Muscat added
# Pakistan, Islamabad
#
# Pakistan Islamabad added
# Palau, Melekeok
#
# Palau Melekeok added
# Panama, Panama City
#
# Panama Panama City added
# Papua New Guinea, Port Moresby
#
# Papua New Guinea Port Moresby added
# Paraguay, Asuncion
#
# Paraguay Asuncion added
# Peru, Lima
#
# Peru Lima added
# Philippines, Manila
#
# Philippines Manila added
# Poland, Warsaw
#
# Poland Warsaw added
# Portugal, Lisbon
#
# Portugal Lisbon added
# Qatar, Doha
#
# Qatar Doha added
# Romania, Bucharest
#
# Romania Bucharest added
# Russia, Moscow
#
# Russia Moscow added
# Rwanda, Kigali
#
# Rwanda Kigali added
# Saint Kitts and Nevis, Basseterre
#
# Saint Kitts and Nevis Basseterre added
# Saint Lucia, Castries
#
# Saint Lucia Castries added
# Saint Vincent and the Grenadines, Kingstown
#
# Saint Vincent and the Grenadines Kingstown added
# Samoa, Apia
#
# Samoa Apia added
# San Marino, San Marino
#
# Country and capital do no have separate vector
# Sao Tome and Principe, Sao Tome
#
# Sao Tome and Principe Sao Tome added
# Saudi Arabia, Riyadh
#
# Saudi Arabia Riyadh added
# Senegal, Dakar
#
# Senegal Dakar added
# Serbia, Belgrade
#
# Serbia Belgrade added
# Seychelles, Victoria
#
# Seychelles Victoria added
# Sierra Leone, Freetown
#
# Sierra Leone Freetown added
# Singapore, Singapore
#
# Country and capital do no have separate vector
# Slovakia, Bratislava
#
# Slovakia Bratislava added
# Slovenia, Ljubljana
#
# Slovenia Ljubljana added
# Solomon Islands, Honiara
#
# Solomon Islands Honiara added
# Somalia, Mogadishu
#
# Somalia Mogadishu added
# South Africa, Pretoria (administrative); Cape Town (legislative); Bloemfontein (judiciary)
#
# South Africa Pretoria (administrative); Cape Town (legislative); Bloemfontein (judiciary) added
# South Sudan, Juba
#
# South Sudan Juba added
# Spain, Madrid
#
# Spain Madrid added
# Sri Lanka, Colombo; Sri Jayewardenepura Kotte (legislative)
#
# Sri Lanka Colombo; Sri Jayewardenepura Kotte (legislative) added
# Sudan, Khartoum
#
# Sudan Khartoum added
# Suriname, Paramaribo
#
# Suriname Paramaribo added
# Swaziland, Mbabane
#
# Swaziland Mbabane added
# Sweden, Stockholm
#
# Sweden Stockholm added
# Switzerland, Bern
#
# Switzerland Bern added
# Syria, Damascus
#
# Syria Damascus added
# Taiwan, Taipei
#
# Taiwan Taipei added
# Tajikistan, Dushanbe
#
# Tajikistan Dushanbe added
# Tanzania, Dar es Salaam; Dodoma (legislative)
#
# Tanzania Dar es Salaam; Dodoma (legislative) added
# Thailand, Bangkok
#
# Thailand Bangkok added
# Togo, Lome
#
# Togo Lome added
# Tonga, Nuku'alofa
#
# Tonga Nuku'alofa added
# Trinidad and Tobago, Port,of,Spain
#
# Skipping Trinidad and Tobago, Port,of,Spain
#
# Tunisia, Tunis
#
# Tunisia Tunis added
# Turkey, Ankara
#
# Turkey Ankara added
# Turkmenistan, Ashgabat
#
# Turkmenistan Ashgabat added
# Tuvalu, Vaiaku village, Funafuti province
#
# Skipping Tuvalu, Vaiaku village, Funafuti province
#
# Uganda, Kampala
#
# Uganda Kampala added
# Ukraine, Kyiv
#
# Ukraine Kyiv added
# United Arab Emirates, Abu Dhabi
#
# United Arab Emirates Abu Dhabi added
# United Kingdom, London
#
# United Kingdom London added
# United States of America, Washington D.C.
#
# United States of America Washington D.C. added
# Uruguay, Montevideo
#
# Uruguay Montevideo added
# Uzbekistan, Tashkent
#
# Uzbekistan Tashkent added
# Vanuatu, Port,Vila
#
# Skipping Vanuatu, Port,Vila
#
# Vatican City (Holy See), Vatican City
#
# Vatican City (Holy See) Vatican City added
# Venezuela, Caracas
#
# Venezuela Caracas added
# Vietnam, Hanoi
#
# Vietnam Hanoi added
# Yemen, Sanaa
#
# Yemen Sanaa added
# Zambia, Lusaka
#
# Zambia Lusaka added
# Zimbabwe, Harare
#
# Zimbabwe Harare added

# %%
def train_new(capital_of, test_size):
    vectors = []
    for country, capital in list(capital_of.items())[:-test_size]:
        try:
            difference_vector = model.wv[country] - model.wv[capital]
            vectors.append(difference_vector)
        except KeyError:
                print('Vector unavailable for training data')
    train_matrix = np.array(vectors)
    m, n = train_matrix.shape
    print("M",m)
    print("N",n)
    X = []
    P = []
    for i in range(300):
        # Split 300-D vectors into 299-D a and 1-D b
        a = np.array(tuple(train_matrix[:,j] for j in range(300) if j != i) ).transpose()# 299 columns
        b = train_matrix[:,i] # i th column
        # print(train_matrix.shape)
        # print(a.shape)
        # print(b.shape)
        # print(i)
        a_transpose = a.transpose()
        # print(a_transpose.shape)
        # print(a_transpose.dot(a).shape)
        # print(np.linalg.inv(a_transpose.dot(a)).shape)
        # print(np.linalg.inv(a_transpose.dot(a)).dot(a_transpose).shape)
        # Find 299x1 dimensional vector x representing our semantic hyperplane
        x = np.linalg.inv(a_transpose.dot(a)).dot(a_transpose).dot(b)
        # find projection p of vector b on this hyperplane 
        p = a.dot(x)
        X.append(x)
        P.append(p)
    return X, P

# %%
    
def project(vector, plane):
    plane_transpose = plane.transpose()
    x = np.linalg.inv(plane_transpose.dot(plane)).dot(plane_transpose).dot(vector)
    p = plane.dot(x)
    return p

# %%
def predict_relationship_new(country, capital, X, cutoff):
    try:
        difference_vector = model.wv[country] - model.wv[capital]
        print("*" * 100)
        print(country, ",", capital)
        differences = []
        for i in range(300):
            # Split 300-D vectors into 299-D a and 1-D b
            actual_output = np.array(tuple(difference_vector[j] for j in range(300) if j != i) ).dot(X[i]) # 299 columns
            expected_output = difference_vector[i] # i th column
            difference_in_output = expected_output-actual_output
            differences.append(difference_in_output)
            # print("Actual output:", actual_output)
            # print("Expected output:", expected_output)
            # print("Difference:", difference_in_output) 
        # print(differences)
        differences_vector_norm = np.linalg.norm(np.array(differences))
        print(differences_vector_norm)
        if(differences_vector_norm < cutoff):
            print("Capital_of relationship identified")
            return True
        else:
            print("Not Capital_of relationship")
            return False
        print("*" * 100)
    except KeyError:
        print('Vector unavailable for testing data')
        return None

# %%
test_size = 20
cutoff = 750
X, P = train_new(capital_of, test_size)
# print(X)
# print(P)
# Out:
# /Users/vikasnagare/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# Vector unavailable for training data
# M 113
# N 300

# %%
print("*" * 200)
print("Testing train data")
train_prediction_true = 0
train_prediction_false = 0
total = 0
for country, capital in list(capital_of.items())[:-test_size]:
    prediction = predict_relationship_new(country, capital, X, cutoff)
    if prediction == True:
        train_prediction_true += 1
    elif prediction == False:
        train_prediction_false += 1
total += (train_prediction_true + train_prediction_false)
print("*" * 200)

print("\n\n\n")
# Out:
# ********************************************************************************************************************************************************************************************************
# Testing train data
# ****************************************************************************************************
# Afghanistan , Kabul
# 238.81683
# Capital_of relationship identified
# ****************************************************************************************************
# Albania , Tirana
# 503.0289
# Capital_of relationship identified
# ****************************************************************************************************
# Algeria , Algiers
# 485.14056
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Angola , Luanda
# 386.162
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Armenia , Yerevan
# 125.00855
# Capital_of relationship identified
# ****************************************************************************************************
# Australia , Canberra
# 265.3647
# Capital_of relationship identified
# ****************************************************************************************************
# Austria , Vienna
# /Users/vikasnagare/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 257.72842
# Capital_of relationship identified
# ****************************************************************************************************
# Azerbaijan , Baku
# 107.51273
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Bahrain , Manama
# 178.33926
# Capital_of relationship identified
# ****************************************************************************************************
# Bangladesh , Dhaka
# 228.0434
# Capital_of relationship identified
# ****************************************************************************************************
# Barbados , Bridgetown
# 160.25189
# Capital_of relationship identified
# ****************************************************************************************************
# Belarus , Minsk
# 279.10248
# Capital_of relationship identified
# ****************************************************************************************************
# Belgium , Brussels
# 351.13235
# Capital_of relationship identified
# ****************************************************************************************************
# Belize , Belmopan
# 268.7238
# Capital_of relationship identified
# ****************************************************************************************************
# Bhutan , Thimphu
# 555.3453
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Botswana , Gaborone
# 169.78741
# Capital_of relationship identified
# ****************************************************************************************************
# Brazil , Brasilia
# 351.5576
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Bulgaria , Sofia
# 189.55199
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Burundi , Bujumbura
# 336.5654
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Cameroon , Yaounde
# 811.42035
# Not Capital_of relationship
# ****************************************************************************************************
# Canada , Ottawa
# 353.2033
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Chad , N'Djamena
# 860.52106
# Not Capital_of relationship
# ****************************************************************************************************
# Chile , Santiago
# 173.99323
# Capital_of relationship identified
# ****************************************************************************************************
# China , Beijing
# 87.86249
# Capital_of relationship identified
# ****************************************************************************************************
# Colombia , Bogota
# 278.5317
# Capital_of relationship identified
# ****************************************************************************************************
# Comoros , Moroni
# 356.65036
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Croatia , Zagreb
# 192.9338
# Capital_of relationship identified
# ****************************************************************************************************
# Cuba , Havana
# 346.86877
# Capital_of relationship identified
# ****************************************************************************************************
# Cyprus , Nicosia
# 375.88858
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Denmark , Copenhagen
# 439.52658
# Capital_of relationship identified
# ****************************************************************************************************
# Dominica , Roseau
# 219.28603
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Ecuador , Quito
# 337.28912
# Capital_of relationship identified
# ****************************************************************************************************
# Egypt , Cairo
# 135.81552
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Eritrea , Asmara
# 350.32074
# Capital_of relationship identified
# ****************************************************************************************************
# Estonia , Tallinn
# 215.67894
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Fiji , Suva
# 354.402
# Capital_of relationship identified
# ****************************************************************************************************
# Finland , Helsinki
# 419.538
# Capital_of relationship identified
# ****************************************************************************************************
# France , Paris
# 240.94148
# Capital_of relationship identified
# ****************************************************************************************************
# Gabon , Libreville
# 307.2693
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Georgia , Tbilisi
# 262.62195
# Capital_of relationship identified
# ****************************************************************************************************
# Germany , Berlin
# 203.25098
# Capital_of relationship identified
# ****************************************************************************************************
# Ghana , Accra
# 257.94794
# Capital_of relationship identified
# ****************************************************************************************************
# Greece , Athens
# 217.57106
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Guinea , Conakry
# 721.4966
# Capital_of relationship identified
# ****************************************************************************************************
# Guyana , Georgetown
# 330.61813
# Capital_of relationship identified
# ****************************************************************************************************
# Honduras , Tegucigalpa
# 246.81233
# Capital_of relationship identified
# ****************************************************************************************************
# Hungary , Budapest
# 228.96468
# Capital_of relationship identified
# ****************************************************************************************************
# Iceland , Reykjavik
# 392.64197
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Indonesia , Jakarta
# 157.20398
# Capital_of relationship identified
# ****************************************************************************************************
# Iran , Tehran
# 158.17531
# Capital_of relationship identified
# ****************************************************************************************************
# Iraq , Baghdad
# 111.77673
# Capital_of relationship identified
# ****************************************************************************************************
# Ireland , Dublin
# 284.90814
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Italy , Rome
# 275.911
# Capital_of relationship identified
# ****************************************************************************************************
# Jamaica , Kingston
# 169.55862
# Capital_of relationship identified
# ****************************************************************************************************
# Japan , Tokyo
# 175.18253
# Capital_of relationship identified
# ****************************************************************************************************
# Jordan , Amman
# 244.56248
# Capital_of relationship identified
# ****************************************************************************************************
# Kazakhstan , Astana
# 171.29227
# Capital_of relationship identified
# ****************************************************************************************************
# Kenya , Nairobi
# 105.63209
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Kosovo , Pristina
# 141.11726
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Kyrgyzstan , Bishkek
# 210.94543
# Capital_of relationship identified
# ****************************************************************************************************
# Laos , Vientiane
# 438.18973
# Capital_of relationship identified
# ****************************************************************************************************
# Latvia , Riga
# 396.35757
# Capital_of relationship identified
# ****************************************************************************************************
# Lebanon , Beirut
# 433.34268
# Capital_of relationship identified
# ****************************************************************************************************
# Lesotho , Maseru
# 275.7928
# Capital_of relationship identified
# ****************************************************************************************************
# Liberia , Monrovia
# 295.3344
# Capital_of relationship identified
# ****************************************************************************************************
# Libya , Tripoli
# 122.68604
# Capital_of relationship identified
# ****************************************************************************************************
# Liechtenstein , Vaduz
# 499.64023
# Capital_of relationship identified
# ****************************************************************************************************
# Lithuania , Vilnius
# 205.04248
# Capital_of relationship identified
# ****************************************************************************************************
# Macedonia , Skopje
# 205.86548
# Capital_of relationship identified
# ****************************************************************************************************
# Madagascar , Antananarivo
# 780.1347
# Not Capital_of relationship
# ****************************************************************************************************
# Malawi , Lilongwe
# 227.67793
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Maldives , Male
# 454.5146
# Capital_of relationship identified
# ****************************************************************************************************
# Mali , Bamako
# 318.13318
# Capital_of relationship identified
# ****************************************************************************************************
# Malta , Valletta
# 310.8085
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Mauritania , Nouakchott
# 560.4213
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Moldova , Chisinau
# 194.02406
# Capital_of relationship identified
# ****************************************************************************************************
# Mongolia , Ulaanbaatar
# 428.4722
# Capital_of relationship identified
# ****************************************************************************************************
# Montenegro , Podgorica
# 358.54175
# Capital_of relationship identified
# ****************************************************************************************************
# Morocco , Rabat
# 380.10077
# Capital_of relationship identified
# ****************************************************************************************************
# Mozambique , Maputo
# 264.88824
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Namibia , Windhoek
# 424.92468
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Nepal , Kathmandu
# 113.647896
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Nicaragua , Managua
# 199.4017
# Capital_of relationship identified
# ****************************************************************************************************
# Niger , Niamey
# 398.32385
# Capital_of relationship identified
# ****************************************************************************************************
# Nigeria , Abuja
# 172.2793
# Capital_of relationship identified
# ****************************************************************************************************
# Norway , Oslo
# 213.14995
# Capital_of relationship identified
# ****************************************************************************************************
# Oman , Muscat
# 235.46262
# Capital_of relationship identified
# ****************************************************************************************************
# Pakistan , Islamabad
# 226.10426
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Paraguay , Asuncion
# 458.85703
# Capital_of relationship identified
# ****************************************************************************************************
# Peru , Lima
# 331.8722
# Capital_of relationship identified
# ****************************************************************************************************
# Philippines , Manila
# 146.83571
# Capital_of relationship identified
# ****************************************************************************************************
# Poland , Warsaw
# 417.69098
# Capital_of relationship identified
# ****************************************************************************************************
# Portugal , Lisbon
# 437.44962
# Capital_of relationship identified
# ****************************************************************************************************
# Qatar , Doha
# 186.1766
# Capital_of relationship identified
# ****************************************************************************************************
# Romania , Bucharest
# 305.44693
# Capital_of relationship identified
# ****************************************************************************************************
# Russia , Moscow
# 141.33803
# Capital_of relationship identified
# ****************************************************************************************************
# Rwanda , Kigali
# 137.24213
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Samoa , Apia
# 314.04126
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Senegal , Dakar
# 238.20235
# Capital_of relationship identified
# ****************************************************************************************************
# Serbia , Belgrade
# 210.52335
# Capital_of relationship identified
# ****************************************************************************************************
# Seychelles , Victoria
# 283.86737
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Slovakia , Bratislava
# 311.4211
# Capital_of relationship identified
# ****************************************************************************************************
# Slovenia , Ljubljana
# 411.83237
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Somalia , Mogadishu
# 184.33342
# Capital_of relationship identified
# Vector unavailable for testing data
# Vector unavailable for testing data
# ****************************************************************************************************
# Spain , Madrid
# 212.97241
# Capital_of relationship identified
# Vector unavailable for testing data
# ****************************************************************************************************
# Sudan , Khartoum
# 223.96889
# Capital_of relationship identified
# ****************************************************************************************************
# Suriname , Paramaribo
# 191.57336
# Capital_of relationship identified
# ****************************************************************************************************
# Swaziland , Mbabane
# 232.25655
# Capital_of relationship identified
# ****************************************************************************************************
# Sweden , Stockholm
# 242.2636
# Capital_of relationship identified
# ****************************************************************************************************
# Switzerland , Bern
# 591.21796
# Capital_of relationship identified
# ****************************************************************************************************
# Syria , Damascus
# 313.61612
# Capital_of relationship identified
# ****************************************************************************************************
# Taiwan , Taipei
# 198.91942
# Capital_of relationship identified
# ****************************************************************************************************
# Tajikistan , Dushanbe
# 170.06032
# Capital_of relationship identified
# ********************************************************************************************************************************************************************************************************

# %%
print("*" * 200)
print("Testing test data")
test_prediction_true = 0
test_prediction_false = 0

for country, capital in list(capital_of.items())[-test_size:]:
    prediction = predict_relationship_new(country, capital, X, cutoff)
    if prediction == True:
        test_prediction_true += 1
    elif prediction == False:
        test_prediction_false += 1
total += (test_prediction_true + test_prediction_false)
print("*" * 200)
print("\n\n\n")

# %%
print("*" * 200)
print("Train data positive:", train_prediction_true)
print("Train data negative:", train_prediction_false)
accuracy = train_prediction_true / (train_prediction_false + train_prediction_true)
print("Train data positive accuracy:", accuracy, accuracy * 100, "%")
print("*" * 200)

print("\n\n\n")

print("\n\n\n")

print("*" * 200)
print("Test data positive:", test_prediction_true)
print("Test data negative:", test_prediction_false)
accuracy = test_prediction_true / (test_prediction_false + test_prediction_true)
print("Test data positive accuracy:", accuracy, accuracy * 100, "%") 
print("*" * 200)

print("\n\n\n")
# Out:
# ********************************************************************************************************************************************************************************************************
# Train data positive: 110
# Train data negative: 3
# Train data positive accuracy: 0.9734513274336283 97.34513274336283 %
# ********************************************************************************************************************************************************************************************************
#
#
#
#
#
#
#
#
# ********************************************************************************************************************************************************************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d8a7435726fc> in <module>
#      11
#      12 print("*" * 200)
# ---> 13 print("Test data positive:", test_prediction_true)
#      14 print("Test data negative:", test_prediction_false)
#      15 accuracy = test_prediction_true / (test_prediction_false + test_prediction_true)
#
# NameError: name 'test_prediction_true' is not defined
